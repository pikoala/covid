# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr,pearsonr
from scipy.optimize import curve_fit
import csv
import urllib
import pandas as pd
import io
import requests
from datetime import date,datetime
import pickle

# %%
url = 'https://raw.githubusercontent.com/amel-github/covid19-interventionmeasures/master/COVID19_non-pharmaceutical-interventions.csv'
s=requests.get(url).content
#print(s)
c=pd.read_csv(io.StringIO(s.decode('latin_1')))
#for row in s.decode('latin_1').split("\r\n"):
#    row.split

# %%
c_it = c[c["Country"] == "Italy"]
#c_it["Date"] = pd.to_datetime(c_it.Date)

# %%
today = datetime.today()

for r in c_it.iterrows():
    this_date = datetime.strptime(r[1][3],"%d/%m/%Y")
    td = int((today - this_date).days)
    if td < 0:
        print("err")
    else:
        print(c_it.loc[r[0]])
        c_it.loc[r[0]]["Date"] = this_date.strftime("%Y-%m-%d")
# Out:
# Country                                           Italy
# iso3c                                               ITA
# Region        10 municipalities in Lombardia and Veneto
# Date                                         02/03/2020
# Measure_L1                           Travel restriction
# Measure_L2                       Stop public transports
# Measure_L3                                          NaN
# Measure_L4                                          NaN
# Comment                                             NaN
# Source                             gazzettaufficiale.it
# Name: 850, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 851, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Reduction of excursions, out-of-house events
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 852, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                   Travel restriction
# Measure_L2                                     Cordon sanitaire
# Measure_L3                                   More than one city
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 853, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                       Recommendation for home office
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 854, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3                    Complete prohibition of gathering
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 855, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3             Conferences, meetings, trade fairs, etc.
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 856, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3               Closure of non-essential public places
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 857, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                         Small gathering cancellation
# Measure_L3                       Closure of non-essential shops
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 858, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                             10 municipality in Lombardia
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                         Small gathering cancellation
# Measure_L3                Police and army control and sanctions
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 859, dtype: object
# Country                                   Italy
# iso3c                                       ITA
# Region                           Emilia Romagna
# Date                                 19/03/2020
# Measure_L1                   Travel restriction
# Measure_L2     Individual movement restrictions
# Measure_L3    Non-essential movements forbidden
# Measure_L4      Walks and bike riding forbidden
# Comment                                     NaN
# Source                     gazzettaufficiale.it
# Name: 860, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region        Emilia Romagna, Friuli Venezia Giulia, Lombard...
# Date                                                 25/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3             Conferences, meetings, trade fairs, etc.
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                                     gazzettaufficiale.it
# Name: 861, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region        Emilia Romagna, Friuli Venezia Giulia, Lombard...
# Date                                                 25/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                       Recommendation for home office
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 862, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 31/01/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                Enhance emergency response mechanisms
# Measure_L3                              Declare emergency state
# Measure_L4                                                  NaN
# Comment                          Declaration of emergency state
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 863, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                                         Italy
# Date                                      22/01/2020
# Measure_L1     Healthcare and public health capacity
# Measure_L2     Enhance emergency response mechanisms
# Measure_L3                       Set up crisis units
# Measure_L4                                  national
# Comment                            set up task force
# Source        Italian health ministery salute.gov.it
# Name: 864, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 23/01/2020
# Measure_L1                                   Risk communication
# Measure_L2    Actively communicate with healthcare professio...
# Measure_L3    Sensitization of hospital, medico-social and l...
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                                                      NaN
# Name: 865, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                                         Italy
# Date                                      25/01/2020
# Measure_L1                        Risk communication
# Measure_L2    Actively communicate with stakeholders
# Measure_L3                                       NaN
# Measure_L4                                       NaN
# Comment        Meeting with the heads of the regions
# Source        Italian health ministery salute.gov.it
# Name: 866, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 04/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                  Border health check
# Measure_L3                         All airports and all harbors
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 867, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                                         Italy
# Date                                      30/01/2020
# Measure_L1                        Travel restriction
# Measure_L2                        Border restriction
# Measure_L3      Borders closed for people from China
# Measure_L4                                       NaN
# Comment       Closed airports for flights from China
# Source        Italian health ministery salute.gov.it
# Name: 868, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 25/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4    Complete closure of universities, research ins...
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 869, dtype: object
# Country                                              Italy
# iso3c                                                  ITA
# Region                                               Italy
# Date                                            02/03/2020
# Measure_L1                               Social distancing
# Measure_L2             Closure of educational institutions
# Measure_L3    Complete closure of educational institutions
# Measure_L4                                             NaN
# Comment                                                NaN
# Source                                gazzettaufficiale.it
# Name: 870, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 25/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Reduction of excursions, out-of-house events
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://it.wikipedia.org/wiki/Pandemia_di_COVI...
# Name: 871, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 16/03/2020
# Measure_L1                                  Resource allocation
# Measure_L2                              Crisis management plans
# Measure_L3    Develop all-of-society and business continuity...
# Measure_L4                                                  NaN
# Comment                                         25 million euro
# Source                   Italian health ministery salute.gov.it
# Name: 872, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 04/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                 Activate communication to the public
# Measure_L4                                              Twitter
# Comment       The searches for corona on Twitter will sugges...
# Source                   Italian health ministery salute.gov.it
# Name: 873, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 07/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                 Activate communication to the public
# Measure_L4                                             Facebook
# Comment       The searches for corona on Facebook will sugge...
# Source                   Italian health ministery salute.gov.it
# Name: 874, dtype: object
# Country                                                  Italy
# iso3c                                                      ITA
# Region                                                   Italy
# Date                                                25/02/2020
# Measure_L1                                  Risk communication
# Measure_L2    Educate and actively communicate with the public
# Measure_L3                 Enhance communication to the public
# Measure_L4                             Spot in the national TV
# Comment                                                    NaN
# Source                  Italian health ministery salute.gov.it
# Name: 875, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 01/03/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4                            Communication on Facebook
# Comment       The health minister writes on Facebook to foll...
# Source                   Italian health ministery salute.gov.it
# Name: 876, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 02/03/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4    hang in pulic spaces (schools, universities, o...
# Comment                                                     NaN
# Source                                     gazzettaufficiale.it
# Name: 877, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 17/03/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4                            Communication on Facebook
# Comment       The health minister writes on Facebook a messa...
# Source                   Italian health ministery salute.gov.it
# Name: 878, dtype: object
# Country                                                  Italy
# iso3c                                                      ITA
# Region                                                   Italy
# Date                                                27/01/2020
# Measure_L1                                  Risk communication
# Measure_L2    Educate and actively communicate with the public
# Measure_L3                                 Answer to questions
# Measure_L4                         Telephone hotlines covid-19
# Comment                                                    NaN
# Source                  Italian health ministery salute.gov.it
# Name: 879, dtype: object
# Country                                                  Italy
# iso3c                                                      ITA
# Region                                                   Italy
# Date                                                30/01/2020
# Measure_L1                                  Risk communication
# Measure_L2    Educate and actively communicate with the public
# Measure_L3                                 Answer to questions
# Measure_L4                         Telephone hotlines covid-19
# Comment                           reinforcement of the hotline
# Source                  Italian health ministery salute.gov.it
# Name: 880, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 10/03/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4                            Communication on Facebook
# Comment       The health minister writes on Facebook a messa...
# Source                   Italian health ministery salute.gov.it
# Name: 881, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 11/03/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4                            Communication on Facebook
# Comment       The health minister writes on Facebook a messa...
# Source                   Italian health ministery salute.gov.it
# Name: 882, dtype: object
# Country                                       Italy
# iso3c                                           ITA
# Region                                        Italy
# Date                                     02/03/2020
# Measure_L1    Healthcare and public health capacity
# Measure_L2                     Enhance hand hygiene
# Measure_L3         Hand sanitizers in public spaces
# Measure_L4                                      NaN
# Comment                                         NaN
# Source                         gazzettaufficiale.it
# Name: 883, dtype: object
# Country                                       Italy
# iso3c                                           ITA
# Region                                        Italy
# Date                                     02/03/2020
# Measure_L1    Healthcare and public health capacity
# Measure_L2             Increase availability of PPE
# Measure_L3         PPE for healthcare professionals
# Measure_L4                                      NaN
# Comment                                         NaN
# Source                         gazzettaufficiale.it
# Name: 884, dtype: object
# Country                                            Italy
# iso3c                                                ITA
# Region                                             Italy
# Date                                          09/01/2020
# Measure_L1         Healthcare and public health capacity
# Measure_L2                 Increase healthcare workforce
# Measure_L3    Train medical staff specially for covid-19
# Measure_L4                                     Exercises
# Comment                                              NaN
# Source            Italian health ministery salute.gov.it
# Name: 885, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 23/02/2020
# Measure_L1                                   Travel restriction
# Measure_L2                     Individual movement restrictions
# Measure_L3                    Non-essential movements forbidden
# Measure_L4    Forbidden to leave the municipality one is in,...
# Comment                                                     NaN
# Source                                                      NaN
# Name: 886, dtype: object
# Country                             Italy
# iso3c                                 ITA
# Region                              Italy
# Date                           02/03/2020
# Measure_L1              Social distancing
# Measure_L2    Mass gathering cancellation
# Measure_L3                  (unspecified)
# Measure_L4                            NaN
# Comment                               NaN
# Source               gazzettaufficiale.it
# Name: 887, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 02/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                     Measures for special populations
# Measure_L3       Measures to limit contact to hospital patients
# Measure_L4    Recommendation to reduce contact to hospital p...
# Comment                                                     NaN
# Source                                     gazzettaufficiale.it
# Name: 888, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 02/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                     Measures for special populations
# Measure_L3    Measures to limit contact to long-term care fa...
# Measure_L4    Recommendation to reduce contact to long-term ...
# Comment                                                     NaN
# Source                                     gazzettaufficiale.it
# Name: 889, dtype: object
# Country                    Italy
# iso3c                        ITA
# Region                     Italy
# Date                  09/03/2020
# Measure_L1    Travel restriction
# Measure_L2     National lockdown
# Measure_L3                   NaN
# Measure_L4                   NaN
# Comment                      NaN
# Source                       NaN
# Name: 890, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 21/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                           Quarantine
# Measure_L3                                      Contact persons
# Measure_L4                                                  NaN
# Comment       Everybody that has been in contact with somebo...
# Source                   Italian health ministery salute.gov.it
# Name: 891, dtype: object
# Country                                            Italy
# iso3c                                                ITA
# Region                                             Italy
# Date                                          07/03/2020
# Measure_L1         Healthcare and public health capacity
# Measure_L2        Scale up emergency response mechanisms
# Measure_L3                         Mobilize other forces
# Measure_L4                                           NaN
# Comment       Investments and hiring of health personnel
# Source            Italian health ministery salute.gov.it
# Name: 892, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 08/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                             Enhance detection system
# Measure_L3                   Search for and/or monitor contacts
# Measure_L4                                                  NaN
# Comment       Students and teachers of all schools coming fr...
# Source                   Italian health ministery salute.gov.it
# Name: 893, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 23/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                         Small gathering cancellation
# Measure_L3              Closure of non-essential working places
# Measure_L4                                                  NaN
# Comment       All non-essential firms, companies and factori...
# Source                                     gazzettaufficiale.it
# Name: 894, dtype: object
# Country                              Italy
# iso3c                                  ITA
# Region                               Italy
# Date                            02/03/2020
# Measure_L1               Social distancing
# Measure_L2    Small gathering cancellation
# Measure_L3        Implement part-time work
# Measure_L4                             NaN
# Comment                                NaN
# Source                gazzettaufficiale.it
# Name: 895, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 22/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2               Specific health channel for travellers
# Measure_L3                                           From China
# Measure_L4                                                Wuhan
# Comment                                                     NaN
# Source                                                      NaN
# Name: 896, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                    Italy
# Date                                                 21/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                         Surveillance
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                                                      NaN
# Name: 897, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                                         Italy
# Date                                      14/03/2020
# Measure_L1                         Social distancing
# Measure_L2                     Work safety protocols
# Measure_L3                                       NaN
# Measure_L4                                       NaN
# Comment                                          NaN
# Source        Italian health ministery salute.gov.it
# Name: 898, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                  Milano Malpensa airport
# Date                                                 26/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                 Airport health check
# Measure_L3        Measure temperature for passengers from Hubei
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 899, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                       Milano Malpensa airport
# Date                                      26/01/2020
# Measure_L1                        Travel restriction
# Measure_L2                       Airport restriction
# Measure_L3                                       NaN
# Measure_L4                                       NaN
# Comment                                          NaN
# Source        Italian health ministery salute.gov.it
# Name: 900, dtype: object
# Country                                             Italy
# iso3c                                                 ITA
# Region        Milano Malpensa and Rome Fiumicino airports
# Date                                           27/01/2020
# Measure_L1          Healthcare and public health capacity
# Measure_L2                  Increase healthcare workforce
# Measure_L3     Train medical staff specially for covid-19
# Measure_L4                                      Exercises
# Comment        training for medical staff in the airports
# Source             Italian health ministery salute.gov.it
# Name: 901, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                     Rome
# Date                                                 08/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                   Isolation of cases
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 902, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                     Rome
# Date                                                 03/02/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Hubei
# Measure_L4                                           Quarantine
# Comment       First flight with Italians living in Wuhan lan...
# Source                   Italian health ministery salute.gov.it
# Name: 903, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                                     Rome
# Date                                                 14/02/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Wuhan
# Measure_L4                                           Quarantine
# Comment       17yo living in Wuhan land in Rome and is quara...
# Source                   Italian health ministery salute.gov.it
# Name: 904, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                           Rome Fiumicino
# Date                                                 04/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                 Airport health check
# Measure_L3               Measure temperature for all passengers
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 905, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                   Rome Fiumicino airport
# Date                                                 23/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                 Airport health check
# Measure_L3               Measure temperature for all passengers
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 906, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                   Rome Fiumicino airport
# Date                                                 28/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                 Airport health check
# Measure_L3               Measure temperature for all passengers
# Measure_L4                                                  NaN
# Comment                          4 new scanners for temperature
# Source                   Italian health ministery salute.gov.it
# Name: 907, dtype: object
# Country                                                   Italy
# iso3c                                                       ITA
# Region                                   Rome Fiumicino airport
# Date                                                 28/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2               Specific health channel for travellers
# Measure_L3                                           From China
# Measure_L4                                                Wuhan
# Comment                                                     NaN
# Source                   Italian health ministery salute.gov.it
# Name: 908, dtype: object
# Country                                        Italy
# iso3c                                            ITA
# Region                       Rome Fiumicino airports
# Date                                      24/01/2020
# Measure_L1                        Travel restriction
# Measure_L2                       Airport restriction
# Measure_L3     Denial entry of travellers from China
# Measure_L4                                       NaN
# Comment                                          NaN
# Source        Italian health ministery salute.gov.it
# Name: 909, dtype: object

# %%
c_it = c_it.sort_values("Date")

# %%
with open( "interventions.p", "wb" ) as f:
    pickle.dump( c_it, f )

# %%
c_fr = c[c["Country"] == "France (metropole)"]

today = datetime.today()

for r in c_fr.iterrows():
    this_date = datetime.strptime(r[1][3],"%d/%m/%Y")
    td = int((today - this_date).days)
    if td < 0:
        print("err")
    else:
        print(c_fr.loc[r[0]])
        c_fr.loc[r[0]]["Date"] = this_date.strftime("%Y-%m-%d")

c_fr = c_fr.sort_values("Date")
# Out:
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                                  Corsica
# Date                                                 20/03/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2               Scale up emergency response mechanisms
# Measure_L3                                Mobilize other forces
# Measure_L4    Helicopter army to evacuate sick patients from...
# Comment                                                     NaN
# Source                                                      NaN
# Name: 475, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                  Department Haute-Savoie
# Date                                                 08/02/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3          Partial closure of educational institutions
# Measure_L4                                            3 schools
# Comment       3 schools where the 3 covid19-positive childre...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 476, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                  Department Haute-Savoie
# Date                                                 08/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                Enhance emergency response mechanisms
# Measure_L3                                  Set up crisis units
# Measure_L4                                                  NaN
# Comment                                 Department Haute-Savoie
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 477, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                  Department Haute-Savoie
# Date                                                 09/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                            Increase patient capacity
# Measure_L3                                  Emergency hospitals
# Measure_L4                                                  NaN
# Comment                       Exceptional medical center set up
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 478, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                  Department Haute-Savoie
# Date                                                 08/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                             Enhance detection system
# Measure_L3                   Search for and/or monitor contacts
# Measure_L4                                                  NaN
# Comment                                  Response first cluster
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 479, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 13/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2               Activate emergency response mechanisms
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                              ORSAN plan
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 480, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 10/01/2020
# Measure_L1                                   Risk communication
# Measure_L2    Actively communicate with healthcare professio...
# Measure_L3             Health agencies and emergency healthcare
# Measure_L4                                                  NaN
# Comment       Regional Health Agencies, learned societies (e...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 481, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 14/01/2020
# Measure_L1                                   Risk communication
# Measure_L2    Actively communicate with healthcare professio...
# Measure_L3    Sensitization of hospital, medico-social and l...
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 482, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 16/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4    Complete closure of universities, research ins...
# Comment                             Announced on the 12/03/2020
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 483, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 16/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4                    Complete closure of kindergardens
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 484, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 16/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4    Complete closure of primary and secondary schools
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 485, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 16/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                  Closure of educational institutions
# Measure_L3         Complete closure of educational institutions
# Measure_L4    Complete closure of universities, research ins...
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 486, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 15/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                       Closure of non-essential shops
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 487, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 17/03/2020
# Measure_L1                                  Resource allocation
# Measure_L2                              Crisis management plans
# Measure_L3    Develop all-of-society and business continuity...
# Measure_L4                                   300 milliard Euros
# Comment                                                     NaN
# Source                                                      NaN
# Name: 488, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 14/03/2020
# Measure_L1                                   Travel restriction
# Measure_L2    Denial entry to boats with more than 100 passe...
# Measure_L3                                         Cruise ships
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 489, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 23/01/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                                  Answer to questions
# Measure_L4         Communcation with nationales living in China
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 490, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 25/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                 Activate communication to the public
# Measure_L4                          Posters at railway stations
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 491, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 29/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                  Enhance communication to the public
# Measure_L4                                         Radio and TV
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 492, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 24/01/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                              Information at airports
# Measure_L4                       Flyers and posters at airports
# Comment                         In French, English and Mandarin
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 493, dtype: object
# Country                                     France (metropole)
# iso3c                                                      FRA
# Region                                      France (metropole)
# Date                                                17/03/2020
# Measure_L1                                  Risk communication
# Measure_L2    Educate and actively communicate with the public
# Measure_L3                      Recommendation for home office
# Measure_L4                                                 NaN
# Comment                                                    NaN
# Source                                                     NaN
# Name: 494, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 28/02/2020
# Measure_L1                                   Risk communication
# Measure_L2     Educate and actively communicate with the public
# Measure_L3                 Scale up communication to the public
# Measure_L4    Broadcasting of radio and television preventio...
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 495, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 17/02/2020
# Measure_L1                                   Risk communication
# Measure_L2    Actively communicate with healthcare professio...
# Measure_L3                                Provide documentation
# Measure_L4                                Provide documentation
# Comment        Practical guide sent to healthcare professionals
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 496, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 06/03/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                Enhance emergency response mechanisms
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                 White plan in hospitals
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 497, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 24/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                                  Repurpose hospitals
# Measure_L3         Some hospitals dedicated to covid19 patients
# Measure_L4                                                  NaN
# Comment       Activation of 70 health establishments with SA...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 498, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 24/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                         Increase availability of PPE
# Measure_L3                                           Face masks
# Measure_L4                                           FFP2 masks
# Comment       Order of several million additional FFP2 masks...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 499, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 12/03/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                        Increase healthcare workforce
# Measure_L3        Mobilization of domestic resources for health
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 500, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 12/03/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                            Increase patient capacity
# Measure_L3    Postponement of non-essential care and non-urg...
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 501, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 17/03/2020
# Measure_L1                                   Travel restriction
# Measure_L2                     Individual movement restrictions
# Measure_L3                    Non-essential movements forbidden
# Measure_L4    Attestation on the honor of the person or the ...
# Comment                                                     NaN
# Source             https://www.gouvernement.fr/info-coronavirus
# Name: 502, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 25/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                                   Isolation of cases
# Measure_L3                                                  NaN
# Measure_L4                                                  NaN
# Comment                                        Institut Pasteur
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 503, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 27/01/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                           Enhance laboratory testing
# Measure_L3                Decrease time bewteen test and result
# Measure_L4    Development of a rapid diagnostic test enablin...
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 504, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 24/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2                           Enhance laboratory testing
# Measure_L3             Increase testing capacity (number tests)
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 505, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 09/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3                             Limit up to 1000 persons
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 506, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 05/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3                             Limit up to 5000 persons
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 507, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 14/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3                              Limit up to 100 persons
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 508, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 06/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                     Measures for special populations
# Measure_L3             Measures to limit contact to the elderly
# Measure_L4                                                  NaN
# Comment        Blue plan in establishment for dependent elderly
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 509, dtype: object
# Country       France (metropole)
# iso3c                        FRA
# Region        France (metropole)
# Date                  17/03/2020
# Measure_L1    Travel restriction
# Measure_L2     National lockdown
# Measure_L3                   NaN
# Measure_L4                   NaN
# Comment                      NaN
# Source                       NaN
# Name: 510, dtype: object
# Country                    France (metropole)
# iso3c                                     FRA
# Region                     France (metropole)
# Date                               17/03/2020
# Measure_L1                 Travel restriction
# Measure_L2    Non-essential travels forbidden
# Measure_L3                                NaN
# Measure_L4                                NaN
# Comment                                   NaN
# Source                                    NaN
# Name: 511, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 31/01/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Hubei
# Measure_L4                                           Quarantine
# Comment                                             220 persons
# Source        https://en.wikipedia.org/wiki/2020_coronavirus...
# Name: 512, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 02/02/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Hubei
# Measure_L4                                           Quarantine
# Comment                                                     NaN
# Source        https://en.wikipedia.org/wiki/2020_coronavirus...
# Name: 513, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 09/02/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Hubei
# Measure_L4                                           Quarantine
# Comment                                                     NaN
# Source        https://en.wikipedia.org/wiki/2020_coronavirus...
# Name: 514, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 21/02/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Hubei
# Measure_L4                                           Quarantine
# Comment                              French and European people
# Source        https://en.wikipedia.org/wiki/2020_coronavirus...
# Name: 515, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 19/03/2020
# Measure_L1                                    Social distancing
# Measure_L2    Return operation of nationals living in region...
# Measure_L3                                                Spain
# Measure_L4                                           Quarantine
# Comment                                                     NaN
# Source                                                      NaN
# Name: 516, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 29/02/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2               Scale up emergency response mechanisms
# Measure_L3    Stage 2 of the plan for the prevention and man...
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 517, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 14/03/2020
# Measure_L1                Healthcare and public health capacity
# Measure_L2               Scale up emergency response mechanisms
# Measure_L3    Stage 3 of the plan for the prevention and man...
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 518, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 18/02/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2                             Enhance detection system
# Measure_L3                   Search for and/or monitor contacts
# Measure_L4                                                  NaN
# Comment       Diagnostic assengers Diamond Princess - Three ...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 519, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 06/03/2020
# Measure_L1                                  Resource allocation
# Measure_L2        Fixing price for specific protective products
# Measure_L3                                      Hand sanitizers
# Measure_L4    Publication of the decree governing the sale p...
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 520, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 15/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                          Mass gathering cancellation
# Measure_L3               Closure of non-essential public places
# Measure_L4                                                  NaN
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 521, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region                                       France (metropole)
# Date                                                 15/03/2020
# Measure_L1                                    Social distancing
# Measure_L2                         Small gathering cancellation
# Measure_L3                    Closure of restaurants/bars/cafes
# Measure_L4              Total closure of restaurants/bars/cafes
# Comment                                                     NaN
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 522, dtype: object
# Country                          France (metropole)
# iso3c                                           FRA
# Region                           France (metropole)
# Date                                     17/03/2020
# Measure_L1                        Social distancing
# Measure_L2             Small gathering cancellation
# Measure_L3    Police and army control and sanctions
# Measure_L4                                      NaN
# Comment                                         NaN
# Source                                          NaN
# Name: 523, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region        Paris Charles de Gaulle and Saint-Denis de la ...
# Date                                                 25/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2               Specific health channel for travellers
# Measure_L3                                           From China
# Measure_L4                                                  NaN
# Comment       Paris Charles de Gaulle and Saint-Denis de la ...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 524, dtype: object
# Country                                      France (metropole)
# iso3c                                                       FRA
# Region        Paris Charles de Gaulle and Saint-Denis de la ...
# Date                                                 25/01/2020
# Measure_L1    Case identification, contact tracing and relat...
# Measure_L2               Specific health channel for travellers
# Measure_L3                From high-risk areas other than China
# Measure_L4                                  Hong Kong and Macao
# Comment       Paris Charles de Gaulle and Saint-Denis de la ...
# Source        https://www.gouvernement.fr/info-coronavirus#p...
# Name: 525, dtype: object

# %%
c_fr
# Out:
#                 Country iso3c  \
# 481  France (metropole)   FRA
# 482  France (metropole)   FRA
# 490  France (metropole)   FRA
# 493  France (metropole)   FRA
# 503  France (metropole)   FRA
# 524  France (metropole)   FRA
# 525  France (metropole)   FRA
# 504  France (metropole)   FRA
# 512  France (metropole)   FRA
# 513  France (metropole)   FRA
# 479  France (metropole)   FRA
# 476  France (metropole)   FRA
# 477  France (metropole)   FRA
# 478  France (metropole)   FRA
# 514  France (metropole)   FRA
# 480  France (metropole)   FRA
# 496  France (metropole)   FRA
# 519  France (metropole)   FRA
# 515  France (metropole)   FRA
# 499  France (metropole)   FRA
# 498  France (metropole)   FRA
# 505  France (metropole)   FRA
# 491  France (metropole)   FRA
# 495  France (metropole)   FRA
# 492  France (metropole)   FRA
# 517  France (metropole)   FRA
# 507  France (metropole)   FRA
# 509  France (metropole)   FRA
# 520  France (metropole)   FRA
# 497  France (metropole)   FRA
# 506  France (metropole)   FRA
# 500  France (metropole)   FRA
# 501  France (metropole)   FRA
# 508  France (metropole)   FRA
# 489  France (metropole)   FRA
# 518  France (metropole)   FRA
# 521  France (metropole)   FRA
# 487  France (metropole)   FRA
# 522  France (metropole)   FRA
# 483  France (metropole)   FRA
# 484  France (metropole)   FRA
# 485  France (metropole)   FRA
# 486  France (metropole)   FRA
# 488  France (metropole)   FRA
# 511  France (metropole)   FRA
# 510  France (metropole)   FRA
# 494  France (metropole)   FRA
# 502  France (metropole)   FRA
# 523  France (metropole)   FRA
# 516  France (metropole)   FRA
# 475  France (metropole)   FRA
#
#                                                 Region        Date  \
# 481                                 France (metropole)  2020-01-10
# 482                                 France (metropole)  2020-01-14
# 490                                 France (metropole)  2020-01-23
# 493                                 France (metropole)  2020-01-24
# 503                                 France (metropole)  2020-01-25
# 524  Paris Charles de Gaulle and Saint-Denis de la ...  2020-01-25
# 525  Paris Charles de Gaulle and Saint-Denis de la ...  2020-01-25
# 504                                 France (metropole)  2020-01-27
# 512                                 France (metropole)  2020-01-31
# 513                                 France (metropole)  2020-02-02
# 479                            Department Haute-Savoie  2020-02-08
# 476                            Department Haute-Savoie  2020-02-08
# 477                            Department Haute-Savoie  2020-02-08
# 478                            Department Haute-Savoie  2020-02-09
# 514                                 France (metropole)  2020-02-09
# 480                                 France (metropole)  2020-02-13
# 496                                 France (metropole)  2020-02-17
# 519                                 France (metropole)  2020-02-18
# 515                                 France (metropole)  2020-02-21
# 499                                 France (metropole)  2020-02-24
# 498                                 France (metropole)  2020-02-24
# 505                                 France (metropole)  2020-02-24
# 491                                 France (metropole)  2020-02-25
# 495                                 France (metropole)  2020-02-28
# 492                                 France (metropole)  2020-02-29
# 517                                 France (metropole)  2020-02-29
# 507                                 France (metropole)  2020-03-05
# 509                                 France (metropole)  2020-03-06
# 520                                 France (metropole)  2020-03-06
# 497                                 France (metropole)  2020-03-06
# 506                                 France (metropole)  2020-03-09
# 500                                 France (metropole)  2020-03-12
# 501                                 France (metropole)  2020-03-12
# 508                                 France (metropole)  2020-03-14
# 489                                 France (metropole)  2020-03-14
# 518                                 France (metropole)  2020-03-14
# 521                                 France (metropole)  2020-03-15
# 487                                 France (metropole)  2020-03-15
# 522                                 France (metropole)  2020-03-15
# 483                                 France (metropole)  2020-03-16
# 484                                 France (metropole)  2020-03-16
# 485                                 France (metropole)  2020-03-16
# 486                                 France (metropole)  2020-03-16
# 488                                 France (metropole)  2020-03-17
# 511                                 France (metropole)  2020-03-17
# 510                                 France (metropole)  2020-03-17
# 494                                 France (metropole)  2020-03-17
# 502                                 France (metropole)  2020-03-17
# 523                                 France (metropole)  2020-03-17
# 516                                 France (metropole)  2020-03-19
# 475                                            Corsica  2020-03-20
#
#                                             Measure_L1  \
# 481                                 Risk communication
# 482                                 Risk communication
# 490                                 Risk communication
# 493                                 Risk communication
# 503  Case identification, contact tracing and relat...
# 524  Case identification, contact tracing and relat...
# 525  Case identification, contact tracing and relat...
# 504              Healthcare and public health capacity
# 512                                  Social distancing
# 513                                  Social distancing
# 479  Case identification, contact tracing and relat...
# 476                                  Social distancing
# 477              Healthcare and public health capacity
# 478              Healthcare and public health capacity
# 514                                  Social distancing
# 480              Healthcare and public health capacity
# 496                                 Risk communication
# 519  Case identification, contact tracing and relat...
# 515                                  Social distancing
# 499              Healthcare and public health capacity
# 498              Healthcare and public health capacity
# 505              Healthcare and public health capacity
# 491                                 Risk communication
# 495                                 Risk communication
# 492                                 Risk communication
# 517              Healthcare and public health capacity
# 507                                  Social distancing
# 509                                  Social distancing
# 520                                Resource allocation
# 497              Healthcare and public health capacity
# 506                                  Social distancing
# 500              Healthcare and public health capacity
# 501              Healthcare and public health capacity
# 508                                  Social distancing
# 489                                 Travel restriction
# 518              Healthcare and public health capacity
# 521                                  Social distancing
# 487                                  Social distancing
# 522                                  Social distancing
# 483                                  Social distancing
# 484                                  Social distancing
# 485                                  Social distancing
# 486                                  Social distancing
# 488                                Resource allocation
# 511                                 Travel restriction
# 510                                 Travel restriction
# 494                                 Risk communication
# 502                                 Travel restriction
# 523                                  Social distancing
# 516                                  Social distancing
# 475              Healthcare and public health capacity
#
#                                             Measure_L2  \
# 481  Actively communicate with healthcare professio...
# 482  Actively communicate with healthcare professio...
# 490   Educate and actively communicate with the public
# 493   Educate and actively communicate with the public
# 503                                 Isolation of cases
# 524             Specific health channel for travellers
# 525             Specific health channel for travellers
# 504                         Enhance laboratory testing
# 512  Return operation of nationals living in region...
# 513  Return operation of nationals living in region...
# 479                           Enhance detection system
# 476                Closure of educational institutions
# 477              Enhance emergency response mechanisms
# 478                          Increase patient capacity
# 514  Return operation of nationals living in region...
# 480             Activate emergency response mechanisms
# 496  Actively communicate with healthcare professio...
# 519                           Enhance detection system
# 515  Return operation of nationals living in region...
# 499                       Increase availability of PPE
# 498                                Repurpose hospitals
# 505                         Enhance laboratory testing
# 491   Educate and actively communicate with the public
# 495   Educate and actively communicate with the public
# 492   Educate and actively communicate with the public
# 517             Scale up emergency response mechanisms
# 507                        Mass gathering cancellation
# 509                   Measures for special populations
# 520      Fixing price for specific protective products
# 497              Enhance emergency response mechanisms
# 506                        Mass gathering cancellation
# 500                      Increase healthcare workforce
# 501                          Increase patient capacity
# 508                        Mass gathering cancellation
# 489  Denial entry to boats with more than 100 passe...
# 518             Scale up emergency response mechanisms
# 521                        Mass gathering cancellation
# 487                     Closure of non-essential shops
# 522                       Small gathering cancellation
# 483                Closure of educational institutions
# 484                Closure of educational institutions
# 485                Closure of educational institutions
# 486                Closure of educational institutions
# 488                            Crisis management plans
# 511                    Non-essential travels forbidden
# 510                                  National lockdown
# 494   Educate and actively communicate with the public
# 502                   Individual movement restrictions
# 523                       Small gathering cancellation
# 516  Return operation of nationals living in region...
# 475             Scale up emergency response mechanisms
#
#                                             Measure_L3  \
# 481           Health agencies and emergency healthcare
# 482  Sensitization of hospital, medico-social and l...
# 490                                Answer to questions
# 493                            Information at airports
# 503                                                NaN
# 524                                         From China
# 525              From high-risk areas other than China
# 504              Decrease time bewteen test and result
# 512                                              Hubei
# 513                                              Hubei
# 479                 Search for and/or monitor contacts
# 476        Partial closure of educational institutions
# 477                                Set up crisis units
# 478                                Emergency hospitals
# 514                                              Hubei
# 480                                                NaN
# 496                              Provide documentation
# 519                 Search for and/or monitor contacts
# 515                                              Hubei
# 499                                         Face masks
# 498       Some hospitals dedicated to covid19 patients
# 505           Increase testing capacity (number tests)
# 491               Activate communication to the public
# 495               Scale up communication to the public
# 492                Enhance communication to the public
# 517  Stage 2 of the plan for the prevention and man...
# 507                           Limit up to 5000 persons
# 509           Measures to limit contact to the elderly
# 520                                    Hand sanitizers
# 497                                                NaN
# 506                           Limit up to 1000 persons
# 500      Mobilization of domestic resources for health
# 501  Postponement of non-essential care and non-urg...
# 508                            Limit up to 100 persons
# 489                                       Cruise ships
# 518  Stage 3 of the plan for the prevention and man...
# 521             Closure of non-essential public places
# 487                                                NaN
# 522                  Closure of restaurants/bars/cafes
# 483       Complete closure of educational institutions
# 484       Complete closure of educational institutions
# 485       Complete closure of educational institutions
# 486       Complete closure of educational institutions
# 488  Develop all-of-society and business continuity...
# 511                                                NaN
# 510                                                NaN
# 494                     Recommendation for home office
# 502                  Non-essential movements forbidden
# 523              Police and army control and sanctions
# 516                                              Spain
# 475                              Mobilize other forces
#
#                                             Measure_L4  \
# 481                                                NaN
# 482                                                NaN
# 490       Communcation with nationales living in China
# 493                     Flyers and posters at airports
# 503                                                NaN
# 524                                                NaN
# 525                                Hong Kong and Macao
# 504  Development of a rapid diagnostic test enablin...
# 512                                         Quarantine
# 513                                         Quarantine
# 479                                                NaN
# 476                                          3 schools
# 477                                                NaN
# 478                                                NaN
# 514                                         Quarantine
# 480                                                NaN
# 496                              Provide documentation
# 519                                                NaN
# 515                                         Quarantine
# 499                                         FFP2 masks
# 498                                                NaN
# 505                                                NaN
# 491                        Posters at railway stations
# 495  Broadcasting of radio and television preventio...
# 492                                       Radio and TV
# 517                                                NaN
# 507                                                NaN
# 509                                                NaN
# 520  Publication of the decree governing the sale p...
# 497                                                NaN
# 506                                                NaN
# 500                                                NaN
# 501                                                NaN
# 508                                                NaN
# 489                                                NaN
# 518                                                NaN
# 521                                                NaN
# 487                                                NaN
# 522            Total closure of restaurants/bars/cafes
# 483  Complete closure of universities, research ins...
# 484                  Complete closure of kindergardens
# 485  Complete closure of primary and secondary schools
# 486  Complete closure of universities, research ins...
# 488                                 300 milliard Euros
# 511                                                NaN
# 510                                                NaN
# 494                                                NaN
# 502  Attestation on the honor of the person or the ...
# 523                                                NaN
# 516                                         Quarantine
# 475  Helicopter army to evacuate sick patients from...
#
#                                                Comment  \
# 481  Regional Health Agencies, learned societies (e...
# 482                                                NaN
# 490                                                NaN
# 493                    In French, English and Mandarin
# 503                                   Institut Pasteur
# 524  Paris Charles de Gaulle and Saint-Denis de la ...
# 525  Paris Charles de Gaulle and Saint-Denis de la ...
# 504                                                NaN
# 512                                        220 persons
# 513                                                NaN
# 479                             Response first cluster
# 476  3 schools where the 3 covid19-positive childre...
# 477                            Department Haute-Savoie
# 478                  Exceptional medical center set up
# 514                                                NaN
# 480                                         ORSAN plan
# 496   Practical guide sent to healthcare professionals
# 519  Diagnostic assengers Diamond Princess - Three ...
# 515                         French and European people
# 499  Order of several million additional FFP2 masks...
# 498  Activation of 70 health establishments with SA...
# 505                                                NaN
# 491                                                NaN
# 495                                                NaN
# 492                                                NaN
# 517                                                NaN
# 507                                                NaN
# 509   Blue plan in establishment for dependent elderly
# 520                                                NaN
# 497                            White plan in hospitals
# 506                                                NaN
# 500                                                NaN
# 501                                                NaN
# 508                                                NaN
# 489                                                NaN
# 518                                                NaN
# 521                                                NaN
# 487                                                NaN
# 522                                                NaN
# 483                        Announced on the 12/03/2020
# 484                                                NaN
# 485                                                NaN
# 486                                                NaN
# 488                                                NaN
# 511                                                NaN
# 510                                                NaN
# 494                                                NaN
# 502                                                NaN
# 523                                                NaN
# 516                                                NaN
# 475                                                NaN
#
#                                                 Source
# 481  https://www.gouvernement.fr/info-coronavirus#p...
# 482  https://www.gouvernement.fr/info-coronavirus#p...
# 490  https://www.gouvernement.fr/info-coronavirus#p...
# 493  https://www.gouvernement.fr/info-coronavirus#p...
# 503  https://www.gouvernement.fr/info-coronavirus#p...
# 524  https://www.gouvernement.fr/info-coronavirus#p...
# 525  https://www.gouvernement.fr/info-coronavirus#p...
# 504  https://www.gouvernement.fr/info-coronavirus#p...
# 512  https://en.wikipedia.org/wiki/2020_coronavirus...
# 513  https://en.wikipedia.org/wiki/2020_coronavirus...
# 479  https://www.gouvernement.fr/info-coronavirus#p...
# 476  https://www.gouvernement.fr/info-coronavirus#p...
# 477  https://www.gouvernement.fr/info-coronavirus#p...
# 478  https://www.gouvernement.fr/info-coronavirus#p...
# 514  https://en.wikipedia.org/wiki/2020_coronavirus...
# 480  https://www.gouvernement.fr/info-coronavirus#p...
# 496  https://www.gouvernement.fr/info-coronavirus#p...
# 519  https://www.gouvernement.fr/info-coronavirus#p...
# 515  https://en.wikipedia.org/wiki/2020_coronavirus...
# 499  https://www.gouvernement.fr/info-coronavirus#p...
# 498  https://www.gouvernement.fr/info-coronavirus#p...
# 505  https://www.gouvernement.fr/info-coronavirus#p...
# 491  https://www.gouvernement.fr/info-coronavirus#p...
# 495  https://www.gouvernement.fr/info-coronavirus#p...
# 492  https://www.gouvernement.fr/info-coronavirus#p...
# 517  https://www.gouvernement.fr/info-coronavirus#p...
# 507  https://www.gouvernement.fr/info-coronavirus#p...
# 509  https://www.gouvernement.fr/info-coronavirus#p...
# 520  https://www.gouvernement.fr/info-coronavirus#p...
# 497  https://www.gouvernement.fr/info-coronavirus#p...
# 506  https://www.gouvernement.fr/info-coronavirus#p...
# 500  https://www.gouvernement.fr/info-coronavirus#p...
# 501  https://www.gouvernement.fr/info-coronavirus#p...
# 508  https://www.gouvernement.fr/info-coronavirus#p...
# 489  https://www.gouvernement.fr/info-coronavirus#p...
# 518  https://www.gouvernement.fr/info-coronavirus#p...
# 521  https://www.gouvernement.fr/info-coronavirus#p...
# 487  https://www.gouvernement.fr/info-coronavirus#p...
# 522  https://www.gouvernement.fr/info-coronavirus#p...
# 483  https://www.gouvernement.fr/info-coronavirus#p...
# 484  https://www.gouvernement.fr/info-coronavirus#p...
# 485  https://www.gouvernement.fr/info-coronavirus#p...
# 486  https://www.gouvernement.fr/info-coronavirus#p...
# 488                                                NaN
# 511                                                NaN
# 510                                                NaN
# 494                                                NaN
# 502       https://www.gouvernement.fr/info-coronavirus
# 523                                                NaN
# 516                                                NaN
# 475                                                NaN
